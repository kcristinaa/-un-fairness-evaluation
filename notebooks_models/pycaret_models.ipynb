# %%
import pycaret
from pycaret.classification import *
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pycaret
# ----> 2 from pycaret.classification import *
#       3 import pandas as pd
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pycaret\classification\__init__.py:1
# ----> 1 from pycaret.classification.functional import (
#       2     add_metric,
#       3     automl,
#       4     blend_models,
#       5     calibrate_model,
#       6     check_drift,
#       7     check_fairness,
#       8     compare_models,
#       9     convert_model,
#      10     create_api,
#      11     create_app,
#      12     create_docker,
#      13     create_model,
#      14     dashboard,
#      15     deploy_model,
#      16     ensemble_model,
#      17     evaluate_model,
#      18     finalize_model,
#      19     get_allowed_engines,
#      20     get_config,
#      21     get_current_experiment,
#      22     get_engine,
#      23     get_leaderboard,
#      24     get_logs,
#      25     get_metrics,
#      26     interpret_model,
#      27     load_experiment,
#      28     load_model,
#      29     models,
#      30     optimize_threshold,
#      31     plot_model,
#      32     predict_model,
#      33     pull,
#      34     remove_metric,
#      35     save_experiment,
#      36     save_model,
#      37     set_config,
#      38     set_current_experiment,
#      39     setup,
#      40     stack_models,
#      41     tune_model,
#      42 )
#      43 from pycaret.classification.oop import ClassificationExperiment
#      45 __all__ = [
#      46     "ClassificationExperiment",
#      47     "setup",
#    (...)
#      86     "check_drift",
#      87 ]
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pycaret\classification\functional.py:8
#       5 import pandas as pd
#       6 from joblib.memory import Memory
# ----> 8 from pycaret.classification.oop import ClassificationExperiment
#       9 from pycaret.internal.parallel.parallel_backend import ParallelBackend
#      10 from pycaret.loggers.base_logger import BaseLogger
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pycaret\classification\oop.py:30
#      28 from pycaret.internal.parallel.parallel_backend import ParallelBackend
#      29 from pycaret.internal.pipeline import Pipeline as InternalPipeline
# ---> 30 from pycaret.internal.preprocess.preprocessor import Preprocessor
#      31 from pycaret.internal.pycaret_experiment.non_ts_supervised_experiment import (
#      32     _NonTSSupervisedExperiment,
#      33 )
#      34 from pycaret.internal.validation import is_sklearn_cv_generator
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pycaret\internal\preprocess\preprocessor.py:8
#       6 import numpy as np
#       7 import pandas as pd
# ----> 8 from category_encoders.basen import BaseNEncoder
#       9 from category_encoders.one_hot import OneHotEncoder
#      10 from category_encoders.ordinal import OrdinalEncoder
#
# File ~\AppData\Roaming\Python\Python38\site-packages\category_encoders\__init__.py:9
#       1 """
#       2
#       3 .. module:: category_encoders
#    (...)
#       6
#       7 """
# ----> 9 from category_encoders.backward_difference import BackwardDifferenceEncoder
#      10 from category_encoders.binary import BinaryEncoder
#      11 from category_encoders.gray import GrayEncoder
#
# File ~\AppData\Roaming\Python\Python38\site-packages\category_encoders\backward_difference.py:3
#       1 """Backward difference contrast encoding"""
# ----> 3 from patsy.contrasts import Diff, ContrastMatrix
#       4 import numpy as np
#       6 from category_encoders.base_contrast_encoder import BaseContrastEncoder
#
# ModuleNotFoundError: No module named 'patsy'

# %%
df = pd.read_pickle("../data/depresjon/depresjon_preprocessed.pkl")
df
# Out:
#      user_id    activity  days  gender  age  afftype  melanch  inpatient edu  \
# 0          1  346.550000    11       2    1      2.0      2.0        2.0   1
# 1          1  284.566667    11       2    1      2.0      2.0        2.0   1
# 2          1  279.183333    11       2    1      2.0      2.0        2.0   1
# 3          1  218.783333    11       2    1      2.0      2.0        2.0   1
# 4          1  238.550000    11       2    1      2.0      2.0        2.0   1
# ...      ...         ...   ...     ...  ...      ...      ...        ...  ..
# 9209       9    0.000000    13       2    2      1.0      2.0        2.0   1
# 9210       9   14.600000    13       2    2      1.0      2.0        2.0   1
# 9211       9  511.316667    13       2    2      1.0      2.0        2.0   1
# 9212       9    7.733333    13       2    2      1.0      2.0        2.0   1
# 9213       9   56.750000    13       2    2      1.0      2.0        2.0   1
#
#       marriage  ...  month_sin  weekday_sin  week_sin   day_sin  month_cos  \
# 0          1.0  ...  -0.974928     0.974928 -0.998027  0.988468  -0.222521
# 1          1.0  ...  -0.974928     0.974928 -0.998027  0.988468  -0.222521
# 2          1.0  ...  -0.974928     0.974928 -0.998027  0.988468  -0.222521
# 3          1.0  ...  -0.974928     0.974928 -0.998027  0.988468  -0.222521
# 4          1.0  ...  -0.974928     0.974928 -0.998027  0.988468  -0.222521
# ...        ...  ...        ...          ...       ...       ...        ...
# 9209       1.0  ...  -0.781831     0.433884  -0.24869  0.897805   0.623490
# 9210       1.0  ...  -0.781831     0.433884  -0.24869  0.897805   0.623490
# 9211       1.0  ...  -0.781831     0.433884  -0.24869  0.897805   0.623490
# 9212       1.0  ...  -0.781831     0.433884  -0.24869  0.897805   0.623490
# 9213       1.0  ...  -0.781831     0.433884  -0.24869  0.897805   0.623490
#
#       weekday_cos  week_cos   day_cos  activity_quantile  \
# 0       -0.222521  0.062791  0.151428                  2
# 1       -0.222521  0.062791  0.151428                  2
# 2       -0.222521  0.062791  0.151428                  2
# 3       -0.222521  0.062791  0.151428                  1
# 4       -0.222521  0.062791  0.151428                  1
# ...           ...       ...       ...                ...
# 9209    -0.900969  0.968583 -0.440394                  0
# 9210    -0.900969  0.968583 -0.440394                  1
# 9211    -0.900969  0.968583 -0.440394                  2
# 9212    -0.900969  0.968583 -0.440394                  0
# 9213    -0.900969  0.968583 -0.440394                  1
#
#       user_activity_quantile
# 0                          2
# 1                          2
# 2                          2
# 3                          1
# 4                          2
# ...                      ...
# 9209                       0
# 9210                       0
# 9211                       2
# 9212                       0
# 9213                       1
#
# [8850 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['user_id', 'activity', 'days', 'gender', 'age', 'afftype', 'melanch',
#        'inpatient', 'edu', 'marriage', 'work', 'is_weekend', 'category_madrs',
#        'month_sin', 'weekday_sin', 'week_sin', 'day_sin', 'month_cos',
#        'weekday_cos', 'week_cos', 'day_cos', 'activity_quantile',
#        'user_activity_quantile'],
#       dtype='object')

# %%
def train_test_split_per_user(data, train_size=0.7):
    users = list(set(data.user_id))
    users = sorted(users, reverse=True)  # fix randomness
    total_users = len(users)
    slice = int(train_size * total_users)
    users_train = users[:slice]
    users_test = users[slice:]
    return data[data.user_id.isin(users_train)], data[data.user_id.isin(users_test)]

# %%
train_data, test_data = train_test_split_per_user(df)

fold_groups = train_data.user_id
train_data = train_data.drop(columns=['user_id'])
test_data = test_data.drop(columns=['user_id'])

# %%
s = setup(data=train_data, target='category_madrs', session_id=123,
          fold_strategy='groupkfold', fold=3,  fold_groups=fold_groups, test_data=test_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23660\1085161084.py in <module>
# ----> 1 s = setup(data=train_data, target='category_madrs', session_id=123,
#       2           fold_strategy='groupkfold', fold=3,  fold_groups=fold_groups, test_data=test_data)
#
# ~\AppData\Roaming\Python\Python39\site-packages\pycaret\classification\functional.py in setup(data, data_func, target, train_size, test_data, ordinal_features, numeric_features, categorical_features, date_features, text_features, ignore_features, keep_features, preprocess, imputation_type, numeric_imputation, categorical_imputation, iterative_imputation_iters, numeric_iterative_imputer, categorical_iterative_imputer, text_features_method, max_encoding_ohe, encoding_method, polynomial_features, polynomial_degree, low_variance_threshold, group_features, group_names, remove_multicollinearity, multicollinearity_threshold, bin_numeric_features, remove_outliers, outliers_method, outliers_threshold, fix_imbalance, fix_imbalance_method, transformation, transformation_method, normalize, normalize_method, pca, pca_method, pca_components, feature_selection, feature_selection_method, feature_selection_estimator, n_features_to_select, custom_pipeline, custom_pipeline_position, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, html, session_id, system_log, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, verbose, memory, profile, profile_kwargs)
#     562     exp = _EXPERIMENT_CLASS()
#     563     set_current_experiment(exp)
# --> 564     return exp.setup(
#     565         data=data,
#     566         data_func=data_func,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pycaret\classification\oop.py in setup(self, data, data_func, target, train_size, test_data, ordinal_features, numeric_features, categorical_features, date_features, text_features, ignore_features, keep_features, preprocess, imputation_type, numeric_imputation, categorical_imputation, iterative_imputation_iters, numeric_iterative_imputer, categorical_iterative_imputer, text_features_method, max_encoding_ohe, encoding_method, polynomial_features, polynomial_degree, low_variance_threshold, group_features, group_names, remove_multicollinearity, multicollinearity_threshold, bin_numeric_features, remove_outliers, outliers_method, outliers_threshold, fix_imbalance, fix_imbalance_method, transformation, transformation_method, normalize, normalize_method, pca, pca_method, pca_components, feature_selection, feature_selection_method, feature_selection_estimator, n_features_to_select, custom_pipeline, custom_pipeline_position, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, html, session_id, system_log, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, engines, verbose, memory, profile, profile_kwargs)
#     848             self.pipeline.steps.remove(("placeholder", None))
#     849
# --> 850         self.pipeline.fit(self.X_train, self.y_train)
#     851
#     852         self.logger.info("Finished creating preprocessing pipeline.")
#
# ~\AppData\Roaming\Python\Python39\site-packages\pycaret\internal\pipeline.py in fit(self, X, y, **fit_params)
#     151     def fit(self, X=None, y=None, **fit_params):
#     152         fit_params_steps = self._check_fit_params(**fit_params)
# --> 153         X, y, _ = self._fit(X, y, **fit_params_steps)
#     154
#     155         with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#
# ~\AppData\Roaming\Python\Python39\site-packages\pycaret\internal\pipeline.py in _fit(self, X, y, **fit_params_steps)
#     132
#     133                 # Fit or load the current transformer from cache
# --> 134                 X, y, fitted_transformer = self._memory_fit(
#     135                     transformer=cloned,
#     136                     X=X,
#
# ~\anaconda3\lib\site-packages\joblib\memory.py in __call__(self, *args, **kwargs)
#     592
#     593     def __call__(self, *args, **kwargs):
# --> 594         return self._cached_call(args, kwargs)[0]
#     595
#     596     def __getstate__(self):
#
# ~\anaconda3\lib\site-packages\joblib\memory.py in _cached_call(self, args, kwargs, shelving)
#     535
#     536         if must_call:
# --> 537             out, metadata = self.call(*args, **kwargs)
#     538             if self.mmap_mode is not None:
#     539                 # Memmap the output at the first call to be consistent with
#
# ~\anaconda3\lib\site-packages\joblib\memory.py in call(self, *args, **kwargs)
#     777         if self._verbose > 0:
#     778             print(format_call(self.func, args, kwargs))
# --> 779         output = self.func(*args, **kwargs)
#     780         self.store_backend.dump_item(
#     781             [func_id, args_id], output, verbose=self._verbose)
#
# ~\AppData\Roaming\Python\Python39\site-packages\pycaret\internal\pipeline.py in _fit_transform_one(transformer, X, y, message, **fit_params)
#      67 def _fit_transform_one(transformer, X=None, y=None, message=None, **fit_params):
#      68     """Fit and transform the data using one transformer."""
# ---> 69     _fit_one(transformer, X, y, message, **fit_params)
#      70     X, y = _transform_one(transformer, X, y)
#      71
#
# ~\AppData\Roaming\Python\Python39\site-packages\pycaret\internal\pipeline.py in _fit_one(transformer, X, y, message, **fit_params)
#      34             if "y" in signature(transformer.fit).parameters:
#      35                 args.append(y)
# ---> 36             transformer.fit(*args, **fit_params)
#      37
#      38
#
# ~\AppData\Roaming\Python\Python39\site-packages\pycaret\internal\preprocess\transformers.py in fit(self, X, y, **fit_params)
#     207             args.append(y)
#     208
# --> 209         self.transformer.fit(*args, **fit_params)
#     210         return self
#     211
#
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\impute\_base.py in fit(self, X, y)
#     380             and not isinstance(fill_value, numbers.Real)
#     381         ):
# --> 382             raise ValueError(
#     383                 "'fill_value'={0} is invalid. Expected a "
#     384                 "numerical value when imputing numerical "
#
# ValueError: 'fill_value'=constant is invalid. Expected a numerical value when imputing numerical data

# %%
best = compare_models(sort = 'acc')
