# %%
import pycaret
from pycaret.classification import *
import pandas as pd

# %%
df = pd.read_pickle("../data/depresjon/depresjon_preprocessed.pkl")
df
# Out:
#        user_id  activity  days  gender  age  afftype  melanch  inpatient edu  \
# 0            1         0    11       2    1      2.0      2.0        2.0   1
# 1            1       143    11       2    1      2.0      2.0        2.0   1
# 2            1         0    11       2    1      2.0      2.0        2.0   1
# 3            1        20    11       2    1      2.0      2.0        2.0   1
# 4            1       166    11       2    1      2.0      2.0        2.0   1
# ...        ...       ...   ...     ...  ...      ...      ...        ...  ..
# 551711       9         0    13       2    2      1.0      2.0        2.0   1
# 551712       9         0    13       2    2      1.0      2.0        2.0   1
# 551713       9       449    13       2    2      1.0      2.0        2.0   1
# 551714       9         0    13       2    2      1.0      2.0        2.0   1
# 551715       9         0    13       2    2      1.0      2.0        2.0   1
#
#         marriage  ...  month_sin  weekday_sin  week_sin   day_sin  month_cos  \
# 0            1.0  ...  -0.974928     0.974928 -0.998027  0.988468  -0.222521
# 1            1.0  ...  -0.974928     0.974928 -0.998027  0.988468  -0.222521
# 2            1.0  ...  -0.974928     0.974928 -0.998027  0.988468  -0.222521
# 3            1.0  ...  -0.974928     0.974928 -0.998027  0.988468  -0.222521
# 4            1.0  ...  -0.974928     0.974928 -0.998027  0.988468  -0.222521
# ...          ...  ...        ...          ...       ...       ...        ...
# 551711       1.0  ...  -0.781831     0.433884  -0.24869  0.897805   0.623490
# 551712       1.0  ...  -0.781831     0.433884  -0.24869  0.897805   0.623490
# 551713       1.0  ...  -0.781831     0.433884  -0.24869  0.897805   0.623490
# 551714       1.0  ...  -0.781831     0.433884  -0.24869  0.897805   0.623490
# 551715       1.0  ...  -0.781831     0.433884  -0.24869  0.897805   0.623490
#
#         weekday_cos  week_cos   day_cos  activity_quantile  \
# 0         -0.222521  0.062791  0.151428                  0
# 1         -0.222521  0.062791  0.151428                  1
# 2         -0.222521  0.062791  0.151428                  0
# 3         -0.222521  0.062791  0.151428                  1
# 4         -0.222521  0.062791  0.151428                  1
# ...             ...       ...       ...                ...
# 551711    -0.900969  0.968583 -0.440394                  1
# 551712    -0.900969  0.968583 -0.440394                  1
# 551713    -0.900969  0.968583 -0.440394                  2
# 551714    -0.900969  0.968583 -0.440394                  1
# 551715    -0.900969  0.968583 -0.440394                  1
#
#         user_activity_quantile
# 0                            0
# 1                            1
# 2                            0
# 3                            1
# 4                            1
# ...                        ...
# 551711                       1
# 551712                       1
# 551713                       2
# 551714                       1
# 551715                       1
#
# [529944 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['user_id', 'activity', 'days', 'gender', 'age', 'afftype', 'melanch',
#        'inpatient', 'edu', 'marriage', 'work', 'is_weekend', 'category_madrs',
#        'month_sin', 'weekday_sin', 'week_sin', 'day_sin', 'month_cos',
#        'weekday_cos', 'week_cos', 'day_cos', 'activity_quantile',
#        'user_activity_quantile'],
#       dtype='object')

# %%
def train_test_split_per_user(data, train_size=0.7):
    users = list(set(data.user_id))
    users = sorted(users, reverse=True)  # fix randomness
    total_users = len(users)
    slice = int(train_size * total_users)
    users_train = users[:slice]
    users_test = users[slice:]
    return data[data.user_id.isin(users_train)], data[data.user_id.isin(users_test)]

# %%
train_data, test_data = train_test_split_per_user(df)

fold_groups = train_data.user_id
train_data = train_data.drop(columns=['user_id'])
test_data = test_data.drop(columns=['user_id'])

# %%
s = setup(data=train_data, target='category_madrs', session_id=123, 
          fold_strategy='groupkfold', fold=3,  fold_groups=fold_groups, test_data=test_data)
# Out:
# <style type="text/css">
# #T_d0d5c_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d0d5c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0d5c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d0d5c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0d5c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d0d5c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d0d5c_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_d0d5c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d0d5c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d0d5c_row1_col1" class="data row1 col1" >category_madrs</td>
#     </tr>
#     <tr>
#       <th id="T_d0d5c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d0d5c_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_d0d5c_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_d0d5c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d0d5c_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_d0d5c_row3_col1" class="data row3 col1" >(529944, 22)</td>
#     </tr>
#     <tr>
#       <th id="T_d0d5c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d0d5c_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_d0d5c_row4_col1" class="data row4 col1" >(529944, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_d0d5c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d0d5c_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_d0d5c_row5_col1" class="data row5 col1" >(370623, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_d0d5c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d0d5c_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_d0d5c_row6_col1" class="data row6 col1" >(159321, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_d0d5c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d0d5c_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_d0d5c_row7_col1" class="data row7 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_d0d5c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d0d5c_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_d0d5c_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_d0d5c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d0d5c_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_d0d5c_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d0d5c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d0d5c_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_d0d5c_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d0d5c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d0d5c_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_d0d5c_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d0d5c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d0d5c_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_d0d5c_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_d0d5c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d0d5c_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_d0d5c_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_d0d5c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d0d5c_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_d0d5c_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d0d5c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d0d5c_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_d0d5c_row15_col1" class="data row15 col1" >GroupKFold</td>
#     </tr>
#     <tr>
#       <th id="T_d0d5c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d0d5c_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_d0d5c_row16_col1" class="data row16 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_d0d5c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d0d5c_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_d0d5c_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d0d5c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d0d5c_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_d0d5c_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d0d5c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d0d5c_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_d0d5c_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d0d5c_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_d0d5c_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_d0d5c_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d0d5c_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_d0d5c_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_d0d5c_row21_col1" class="data row21 col1" >20b3</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models(sort = 'acc')
# Out:
# <style type="text/css">
# #T_bd557 th {
#   text-align: left;
# }
# #T_bd557_row0_col0, #T_bd557_row0_col2, #T_bd557_row0_col3, #T_bd557_row1_col0, #T_bd557_row1_col1, #T_bd557_row1_col2, #T_bd557_row1_col4, #T_bd557_row1_col5, #T_bd557_row1_col6, #T_bd557_row1_col7, #T_bd557_row2_col0, #T_bd557_row2_col1, #T_bd557_row2_col2, #T_bd557_row2_col3, #T_bd557_row2_col4, #T_bd557_row2_col5, #T_bd557_row2_col6, #T_bd557_row2_col7, #T_bd557_row3_col0, #T_bd557_row3_col1, #T_bd557_row3_col2, #T_bd557_row3_col3, #T_bd557_row3_col4, #T_bd557_row3_col5, #T_bd557_row3_col6, #T_bd557_row3_col7, #T_bd557_row4_col0, #T_bd557_row4_col1, #T_bd557_row4_col2, #T_bd557_row4_col3, #T_bd557_row4_col4, #T_bd557_row4_col5, #T_bd557_row4_col6, #T_bd557_row4_col7, #T_bd557_row5_col0, #T_bd557_row5_col1, #T_bd557_row5_col2, #T_bd557_row5_col3, #T_bd557_row5_col4, #T_bd557_row5_col5, #T_bd557_row5_col6, #T_bd557_row5_col7, #T_bd557_row6_col0, #T_bd557_row6_col1, #T_bd557_row6_col3, #T_bd557_row6_col4, #T_bd557_row6_col5, #T_bd557_row6_col6, #T_bd557_row6_col7, #T_bd557_row7_col0, #T_bd557_row7_col1, #T_bd557_row7_col2, #T_bd557_row7_col3, #T_bd557_row7_col4, #T_bd557_row7_col5, #T_bd557_row7_col6, #T_bd557_row7_col7, #T_bd557_row8_col0, #T_bd557_row8_col1, #T_bd557_row8_col2, #T_bd557_row8_col3, #T_bd557_row8_col4, #T_bd557_row8_col5, #T_bd557_row8_col6, #T_bd557_row8_col7, #T_bd557_row9_col0, #T_bd557_row9_col1, #T_bd557_row9_col2, #T_bd557_row9_col3, #T_bd557_row9_col4, #T_bd557_row9_col5, #T_bd557_row9_col6, #T_bd557_row9_col7, #T_bd557_row10_col0, #T_bd557_row10_col1, #T_bd557_row10_col2, #T_bd557_row10_col3, #T_bd557_row10_col4, #T_bd557_row10_col5, #T_bd557_row10_col6, #T_bd557_row10_col7, #T_bd557_row11_col0, #T_bd557_row11_col1, #T_bd557_row11_col2, #T_bd557_row11_col3, #T_bd557_row11_col4, #T_bd557_row11_col5, #T_bd557_row11_col6, #T_bd557_row11_col7, #T_bd557_row12_col0, #T_bd557_row12_col1, #T_bd557_row12_col2, #T_bd557_row12_col3, #T_bd557_row12_col4, #T_bd557_row12_col5, #T_bd557_row12_col6, #T_bd557_row12_col7, #T_bd557_row13_col0, #T_bd557_row13_col1, #T_bd557_row13_col2, #T_bd557_row13_col3, #T_bd557_row13_col4, #T_bd557_row13_col5, #T_bd557_row13_col6, #T_bd557_row13_col7 {
#   text-align: left;
# }
# #T_bd557_row0_col1, #T_bd557_row0_col4, #T_bd557_row0_col5, #T_bd557_row0_col6, #T_bd557_row0_col7, #T_bd557_row1_col3, #T_bd557_row6_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_bd557_row0_col8, #T_bd557_row1_col8, #T_bd557_row2_col8, #T_bd557_row3_col8, #T_bd557_row4_col8, #T_bd557_row5_col8, #T_bd557_row6_col8, #T_bd557_row7_col8, #T_bd557_row8_col8, #T_bd557_row9_col8, #T_bd557_row10_col8, #T_bd557_row11_col8, #T_bd557_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_bd557_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_bd557">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bd557_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_bd557_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_bd557_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_bd557_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_bd557_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_bd557_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_bd557_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_bd557_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_bd557_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd557_level0_row0" class="row_heading level0 row0" >lda</th>
#       <td id="T_bd557_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_bd557_row0_col1" class="data row0 col1" >0.7147</td>
#       <td id="T_bd557_row0_col2" class="data row0 col2" >0.6259</td>
#       <td id="T_bd557_row0_col3" class="data row0 col3" >0.6380</td>
#       <td id="T_bd557_row0_col4" class="data row0 col4" >0.8273</td>
#       <td id="T_bd557_row0_col5" class="data row0 col5" >0.6932</td>
#       <td id="T_bd557_row0_col6" class="data row0 col6" >0.4061</td>
#       <td id="T_bd557_row0_col7" class="data row0 col7" >0.4411</td>
#       <td id="T_bd557_row0_col8" class="data row0 col8" >1.0767</td>
#     </tr>
#     <tr>
#       <th id="T_bd557_level0_row1" class="row_heading level0 row1" >qda</th>
#       <td id="T_bd557_row1_col0" class="data row1 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_bd557_row1_col1" class="data row1 col1" >0.6407</td>
#       <td id="T_bd557_row1_col2" class="data row1 col2" >0.5827</td>
#       <td id="T_bd557_row1_col3" class="data row1 col3" >0.8329</td>
#       <td id="T_bd557_row1_col4" class="data row1 col4" >0.5659</td>
#       <td id="T_bd557_row1_col5" class="data row1 col5" >0.6693</td>
#       <td id="T_bd557_row1_col6" class="data row1 col6" >0.1623</td>
#       <td id="T_bd557_row1_col7" class="data row1 col7" >0.2010</td>
#       <td id="T_bd557_row1_col8" class="data row1 col8" >0.9733</td>
#     </tr>
#     <tr>
#       <th id="T_bd557_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_bd557_row2_col0" class="data row2 col0" >Ridge Classifier</td>
#       <td id="T_bd557_row2_col1" class="data row2 col1" >0.6157</td>
#       <td id="T_bd557_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_bd557_row2_col3" class="data row2 col3" >0.4821</td>
#       <td id="T_bd557_row2_col4" class="data row2 col4" >0.7245</td>
#       <td id="T_bd557_row2_col5" class="data row2 col5" >0.5617</td>
#       <td id="T_bd557_row2_col6" class="data row2 col6" >0.2447</td>
#       <td id="T_bd557_row2_col7" class="data row2 col7" >0.2524</td>
#       <td id="T_bd557_row2_col8" class="data row2 col8" >0.7800</td>
#     </tr>
#     <tr>
#       <th id="T_bd557_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_bd557_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_bd557_row3_col1" class="data row3 col1" >0.5851</td>
#       <td id="T_bd557_row3_col2" class="data row3 col2" >0.5618</td>
#       <td id="T_bd557_row3_col3" class="data row3 col3" >0.4485</td>
#       <td id="T_bd557_row3_col4" class="data row3 col4" >0.6597</td>
#       <td id="T_bd557_row3_col5" class="data row3 col5" >0.4995</td>
#       <td id="T_bd557_row3_col6" class="data row3 col6" >0.2066</td>
#       <td id="T_bd557_row3_col7" class="data row3 col7" >0.2137</td>
#       <td id="T_bd557_row3_col8" class="data row3 col8" >2.2033</td>
#     </tr>
#     <tr>
#       <th id="T_bd557_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_bd557_row4_col0" class="data row4 col0" >Extra Trees Classifier</td>
#       <td id="T_bd557_row4_col1" class="data row4 col1" >0.5661</td>
#       <td id="T_bd557_row4_col2" class="data row4 col2" >0.6397</td>
#       <td id="T_bd557_row4_col3" class="data row4 col3" >0.4499</td>
#       <td id="T_bd557_row4_col4" class="data row4 col4" >0.7081</td>
#       <td id="T_bd557_row4_col5" class="data row4 col5" >0.4181</td>
#       <td id="T_bd557_row4_col6" class="data row4 col6" >0.0998</td>
#       <td id="T_bd557_row4_col7" class="data row4 col7" >0.1703</td>
#       <td id="T_bd557_row4_col8" class="data row4 col8" >2.0467</td>
#     </tr>
#     <tr>
#       <th id="T_bd557_level0_row5" class="row_heading level0 row5" >svm</th>
#       <td id="T_bd557_row5_col0" class="data row5 col0" >SVM - Linear Kernel</td>
#       <td id="T_bd557_row5_col1" class="data row5 col1" >0.5598</td>
#       <td id="T_bd557_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_bd557_row5_col3" class="data row5 col3" >0.4525</td>
#       <td id="T_bd557_row5_col4" class="data row5 col4" >0.6166</td>
#       <td id="T_bd557_row5_col5" class="data row5 col5" >0.5018</td>
#       <td id="T_bd557_row5_col6" class="data row5 col6" >0.1445</td>
#       <td id="T_bd557_row5_col7" class="data row5 col7" >0.1325</td>
#       <td id
