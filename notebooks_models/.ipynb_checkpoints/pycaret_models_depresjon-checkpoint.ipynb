# %%
import pandas as pd
import pycaret
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from pycaret.classification import *
from imblearn.over_sampling import SMOTE

# %%
df = pd.read_pickle("../data/depresjon/depresjon_preprocessed.pkl")
df
# Out:
#                timestamp  user_id    activity  days  gender  age  afftype  \
# 0    1052265600000000000        1  174.144444    11       0    0      2.0
# 1    1052352000000000000        1  156.247222    11       0    0      2.0
# 2    1052438400000000000        1  124.135417    11       0    0      2.0
# 3    1052524800000000000        1  134.961806    11       0    0      2.0
# 4    1052611200000000000        1   99.439583    11       0    0      2.0
# ..                   ...      ...         ...   ...     ...  ...      ...
# 400  1086480000000000000        9  162.295833    13       0    1      1.0
# 401  1086566400000000000        9  224.508333    13       0    1      1.0
# 402  1086652800000000000        9  202.056250    13       0    1      1.0
# 403  1086739200000000000        9  168.656250    13       0    1      1.0
# 404  1086825600000000000        9  115.589207    13       0    1      1.0
#
#      melanch  inpatient  edu  ...  month_sin  weekday_sin  week_sin   day_sin  \
# 0        2.0        2.0    1  ...  -0.974928     0.974928 -0.998027  0.988468
# 1        2.0        2.0    1  ...  -0.974928     0.433884 -0.998027  0.998717
# 2        2.0        2.0    1  ...  -0.974928    -0.433884 -0.998027  0.968077
# 3        2.0        2.0    1  ...  -0.974928    -0.974928 -0.998027  0.897805
# 4        2.0        2.0    1  ...  -0.974928    -0.781831 -0.998027  0.790776
# ..       ...        ...  ...  ...        ...          ...       ...       ...
# 400      2.0        2.0    1  ...  -0.781831    -0.781831 -0.481754  0.937752
# 401      2.0        2.0    1  ...  -0.781831     0.000000  -0.24869  0.988468
# 402      2.0        2.0    1  ...  -0.781831     0.781831  -0.24869  0.998717
# 403      2.0        2.0    1  ...  -0.781831     0.974928  -0.24869  0.968077
# 404      2.0        2.0    1  ...  -0.781831     0.433884  -0.24869  0.897805
#
#      month_cos  weekday_cos  week_cos   day_cos  activity_quantile  \
# 0    -0.222521    -0.222521  0.062791  0.151428                  1
# 1    -0.222521    -0.900969  0.062791 -0.050649                  1
# 2    -0.222521    -0.900969  0.062791 -0.250653                  1
# 3    -0.222521    -0.222521  0.062791 -0.440394                  1
# 4    -0.222521     0.623490  0.062791 -0.612106                  1
# ..         ...          ...       ...       ...                ...
# 400   0.623490     0.623490  0.876307  0.347305                  1
# 401   0.623490     1.000000  0.968583  0.151428                  1
# 402   0.623490     0.623490  0.968583 -0.050649                  1
# 403   0.623490    -0.222521  0.968583 -0.250653                  1
# 404   0.623490    -0.900969  0.968583 -0.440394                  1
#
#      user_activity_quantile
# 0                         1
# 1                         1
# 2                         1
# 3                         1
# 4                         0
# ..                      ...
# 400                       0
# 401                       2
# 402                       2
# 403                       1
# 404                       0
#
# [389 rows x 24 columns]

# %%
df['category_madrs'].value_counts()
# Out:
# 0    201
# 1    188
# Name: category_madrs, dtype: int64

# %%
def train_test_split_per_user(data, train_size=0.7):
    users = list(set(data.user_id))
    users = sorted(users, reverse=True)  # fix randomness
    total_users = len(users)
    slice = int(train_size * total_users)
    users_train = users[:slice]
    users_test = users[slice:]
    return data[data.user_id.isin(users_train)], data[data.user_id.isin(users_test)]

# %%
train_data, test_data = train_test_split_per_user(df)

fold_groups = train_data.user_id
train_data = train_data.drop(columns=['user_id'])
test_data = test_data.drop(columns=['user_id'])

# %%
X = train_data.drop(columns=['category_madrs'])
y = train_data['category_madrs']

# Apply SMOTE
smote = SMOTE(random_state=123)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Combine resampled data
train_data_resampled = pd.concat([X_resampled, y_resampled], axis=1)

# %%
s = setup(data=train_data_resampled, 
          target='category_madrs', 
          session_id=123, 
          fold_strategy='groupkfold', 
          fold=5,  
          fold_groups=fold_groups, 
          test_data=test_data, 
          normalize=True)
# Out:
# <style type="text/css">
# #T_f88cb_row8_col1, #T_f88cb_row13_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f88cb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f88cb_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f88cb_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f88cb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f88cb_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f88cb_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_f88cb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f88cb_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f88cb_row1_col1" class="data row1 col1" >category_madrs</td>
#     </tr>
#     <tr>
#       <th id="T_f88cb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f88cb_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_f88cb_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_f88cb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f88cb_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_f88cb_row3_col1" class="data row3 col1" >(431, 23)</td>
#     </tr>
#     <tr>
#       <th id="T_f88cb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f88cb_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_f88cb_row4_col1" class="data row4 col1" >(431, 23)</td>
#     </tr>
#     <tr>
#       <th id="T_f88cb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f88cb_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_f88cb_row5_col1" class="data row5 col1" >(306, 23)</td>
#     </tr>
#     <tr>
#       <th id="T_f88cb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f88cb_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_f88cb_row6_col1" class="data row6 col1" >(125, 23)</td>
#     </tr>
#     <tr>
#       <th id="T_f88cb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f88cb_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_f88cb_row7_col1" class="data row7 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_f88cb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f88cb_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_f88cb_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f88cb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f88cb_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_f88cb_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f88cb_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f88cb_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_f88cb_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f88cb_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f88cb_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_f88cb_row11_col1" class="data row11 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_f88cb_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f88cb_row12_col0" class="data row12 col0" >Low variance threshold</td>
#       <td id="T_f88cb_row12_col1" class="data row12 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f88cb_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f88cb_row13_col0" class="data row13 col0" >Normalize</td>
#       <td id="T_f88cb_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f88cb_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f88cb_row14_col0" class="data row14 col0" >Normalize method</td>
#       <td id="T_f88cb_row14_col1" class="data row14 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_f88cb_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f88cb_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_f88cb_row15_col1" class="data row15 col1" >GroupKFold</td>
#     </tr>
#     <tr>
#       <th id="T_f88cb_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f88cb_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_f88cb_row16_col1" class="data row16 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_f88cb_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f88cb_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_f88cb_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f88cb_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f88cb_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_f88cb_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f88cb_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f88cb_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_f88cb_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f88cb_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_f88cb_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_f88cb_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_f88cb_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_f88cb_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_f88cb_row21_col1" class="data row21 col1" >6218</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models(sort = 'F1')
# Out:
# <style type="text/css">
# </style>
# <table id="T_abcf6">
#   <thead>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# Processing:   0%|          | 0/69 [00:00<?, ?it/s]

# %%
predictions = predict_model(best, data=test_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 predictions = predict_model(best, data=test_data)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pycaret\classification\functional.py:2163, in predict_model(estimator, data, probability_threshold, encoded_labels, raw_score, drift_report, round, verbose)
#    2160 if experiment is None:
#    2161     experiment = _EXPERIMENT_CLASS()
# -> 2163 return experiment.predict_model(
#    2164     estimator=estimator,
#    2165     data=data,
#    2166     probability_threshold=probability_threshold,
#    2167     encoded_labels=encoded_labels,
#    2168     raw_score=raw_score,
#    2169     drift_report=drift_report,
#    2170     round=round,
#    2171     verbose=verbose,
#    2172 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pycaret\classification\oop.py:2785, in ClassificationExperiment.predict_model(self, estimator, data, probability_threshold, encoded_labels, raw_score, drift_report, round, verbose)
#    2706 def predict_model(
#    2707     self,
#    2708     estimator,
#    (...)
#    2715     verbose: bool = True,
#    2716 ) -> pd.DataFrame:
#    2718     """
#    2719     This function predicts ``Label`` and ``Score`` (probability of predicted
#    2720     class) using a trained model. When ``data`` is None, it predicts label and
#    (...)
#    2782
#    2783     """
# -> 2785     return super().predict_model(
#    2786         estimator=estimator,
#    2787         data=data,
#    2788         probability_threshold=probability_threshold,
#    2789         encoded_labels=encoded_labels,
#    2790         raw_score=raw_score,
#    2791         drift_report=drift_report,
#    2792         round=round,
#    2793         verbose=verbose,
#    2794     )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py:4999, in _SupervisedExperiment.predict_model(self, estimator, data, probability_threshold, encoded_labels, raw_score, drift_report, round, verbose, ml_usecase, preprocess)
#    4996         probability_threshold = estimator.probability_threshold
#    4997     estimator = get_estimator_from_meta_estimator(estimator)
# -> 4999 pred = np.nan_to_num(estimator.predict(X_test_))
#    5001 try:
#    5002     score = estimator.predict_proba(X_test_)
#
# AttributeError: 'list' object has no attribute 'predict'

# %%
from sklearn.metrics import f1_score

f1 = f1_score(predictions_df['category_madrs'], predictions_df['Label'])

print(f'F1 Score: {f1:.4f}')

# %%
# Extracting X_test (features) - this includes all columns except the label and prediction columns
X_test = predictions.drop(columns=['Label', 'Score'])

# Extracting y_test (true labels)
y_test = predictions['category_madrs']  # Adjust this to your actual target column name

# Extracting y_pred (predicted labels)
y_pred = predictions['Label']

# %%
print(y_pred.value_counts())
print(y_test.value_counts())

# %%
train_data.columns

# %%
test_data.columns

# %%
from sklearn.model_selection import cross_val_score

f1_scores = cross_val_score(best, X_train, y_train, cv=5, scoring='f1')
print(f1_scores)

# %%
y_pred.to_csv('../data/depresjon/predictions/depresjon_pred_generic.csv', index=False)
X_test.to_csv('../data/depresjon/predictions/depresjon_X_test_generic.csv', index=False)
y_test.to_csv('../data/depresjon/predictions/depresjon_y_test_generic.csv', index=False)

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()

# %%
algo = create_model('gbc')

# %%
algo

# %%
#algo.get_all_params()

# %%
tuned_algo = tune_model(algo)

# %%
#tuned_algo.get_all_params()

# %%
tuned_algo

# %%
plot_model(tuned_algo, plot = 'auc')

# %%
plot_model(tuned_algo, plot='feature')

# %%
plot_model(tuned_algo, plot = 'confusion_matrix')

# %%
# Predict on test / hold-out Sample
test_predictions = predict_model(tuned_algo, data=test_data)
